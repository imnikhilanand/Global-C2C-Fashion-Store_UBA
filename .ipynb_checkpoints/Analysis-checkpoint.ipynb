# %% [markdown]
# # Global C2C Fashion Store Analysis

# %% [markdown]
# ### Importing Libraries and Datasets

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# importing the datasets
user_level_data = pd.read_csv("dataset/6M-0K-99K.users.dataset.public.csv")
buyer_by_country = pd.read_csv("dataset/Buyers-repartition-by-country.csv")
seller_by_gender = pd.read_csv("dataset/Comparison-of-Sellers-by-Gender-and-Country.csv")
country_top_sellers = pd.read_csv("dataset/Countries-with-Top-Sellers-(Fashion-C2C).csv")
country_code = pd.read_csv("dataset/country_code.csv")

# %%
# user level data
user_level_data.head(10)
# Out:
#    index       identifierHash  type      country language  socialNbFollowers  \
# 0      0 -7279641312655250028  user   Etats-Unis       en                  3
# 1      1 -1456013578740053406  user    Allemagne       de                  3
# 2      2  9006282053848196165  user        Suède       en                  3
# 3      3 -7154634866120535654  user      Turquie       en                  3
# 4      4  2858299215060733023  user       France       en                  3
# 5      5 -8370972521561479983  user  Royaume-Uni       en                  3
# 6      6 -7877915015908472168  user  Royaume-Uni       en                  3
# 7      7  7455841332634807036  user       Italie       fr                  3
# 8      8  4607255007288453096  user       Italie       fr                  3
# 9      9 -7302797141205914253  user       France       en                  3
#
#    socialNbFollows  socialProductsLiked  productsListed  productsSold  ...  \
# 0                8                    0               0             0  ...
# 1                8                    0               0             0  ...
# 2                8                    0               0             0  ...
# 3                8                    0               0             0  ...
# 4                8                    0               0             0  ...
# 5                8                    0               0             0  ...
# 6                8                    4               0             0  ...
# 7                8                    0               0             0  ...
# 8                8                    0               0             0  ...
# 9                8                    0               0             0  ...
#
#    civilityTitle  hasAnyApp  hasAndroidApp hasIosApp  hasProfilePicture  \
# 0            mrs      False          False     False               True
# 1            mrs      False          False     False               True
# 2             mr       True          False      True               True
# 3            mrs      False          False     False               True
# 4             mr       True          False      True               True
# 5            mrs      False          False     False               True
# 6            mrs      False          False     False               True
# 7            mrs       True           True     False               True
# 8            mrs       True           True     False               True
# 9             mr       True          False      True               True
#
#   daysSinceLastLogin  seniority  seniorityAsMonths  seniorityAsYears  \
# 0                709       3205             106.83               8.9
# 1                709       3205             106.83               8.9
# 2                689       3205             106.83               8.9
# 3                709       3205             106.83               8.9
# 4                709       3205             106.83               8.9
# 5                709       3205             106.83               8.9
# 6                591       3205             106.83               8.9
# 7                709       3205             106.83               8.9
# 8                701       3205             106.83               8.9
# 9                703       3205             106.83               8.9
#
#    countryCode
# 0           us
# 1           de
# 2           se
# 3           tr
# 4           fr
# 5           gb
# 6           gb
# 7           it
# 8           it
# 9           fr
#
# [10 rows x 25 columns]

# %%
# buyer level data
buyer_by_country.head(10)
# Out:
#    index      country  buyers  topbuyers  topbuyerratio  femalebuyers  \
# 0      0       France    1251         53            4.2           851
# 1      1  Royaume-Uni     792         38            4.8           560
# 2      2   Etats-Unis     912         31            3.4           700
# 3      3    Allemagne     578         29            5.0           409
# 4      4       Italie     400         21            5.3           283
# 5      5      Espagne     255         21            8.2           189
# 6      6     Pays-Bas     144         15           10.4           118
# 7      7        Suède     151         11            7.3           113
# 8      8     Finlande      64         10           15.6            53
# 9      9     Danemark     157          9            5.7           127
#
#    malebuyers  topfemalebuyers  topmalebuyers  femalebuyersratio  ...  \
# 0         400               33             20               68.0  ...
# 1         232               30              8               70.7  ...
# 2         212               21             10               76.8  ...
# 3         169               21              8               70.8  ...
# 4         117               14              7               70.8  ...
# 5          66               18              3               74.1  ...
# 6          26               10              5               81.9  ...
# 7          38                7              4               74.8  ...
# 8          11                9              1               82.8  ...
# 9          30                9              0               80.9  ...
#
#    meanproductsliked  topmeanproductsbought  topmeanproductswished  \
# 0               20.2                   28.1                   77.2
# 1               29.5                   22.4                  161.2
# 2               32.8                   27.9                  119.4
# 3               41.1                   17.8                  175.7
# 4               35.5                   24.7                  208.4
# 5               65.0                   26.6                  222.5
# 6               42.7                   19.7                   72.3
# 7               67.9                   21.3                  169.3
# 8               55.7                   21.2                   50.2
# 9              168.2                   15.7                  228.8
#
#    topmeanproductsliked  meanofflinedays  topmeanofflinedays  meanfollowers  \
# 0                 120.9            321.8                75.0            4.8
# 1                 193.7            298.3                68.2            5.4
# 2                 224.1            359.3                73.0            4.9
# 3                 367.2            296.6                39.3            5.1
# 4                 103.4            247.9                40.9            6.4
# 5                 427.8            271.1                39.4            7.0
# 6                 166.5            191.6                14.3            6.3
# 7                 423.5            189.1                86.0            7.4
# 8                  87.4            184.9               121.1            6.7
# 9                 388.8            156.0                19.3            5.6
#
#    meanfollowing  topmeanfollowers  topmeanfollowing
# 0            8.8              10.1              11.0
# 1            8.8              11.1              12.2
# 2            9.7              11.7              27.9
# 3            8.6              11.2              11.3
# 4           11.6              14.3              15.4
# 5            9.5              17.6              11.6
# 6            9.0              17.7              10.5
# 7            9.1              20.2               9.5
# 8            9.2              10.3              12.5
# 9            8.6              11.7               9.7
#
# [10 rows x 33 columns]

# %%
# sellers by gender
seller_by_gender.head(10)
# Out:
#    index    country     sex  nbsellers  meanproductssold  meanproductslisted  \
# 0      0  Allemagne  Female        116              4.03                2.72
# 1      1  Allemagne    Male         34              2.00                1.00
# 2      2    Arménie  Female          1              0.00               25.00
# 3      3  Australie  Female         18              0.94                1.33
# 4      4  Australie    Male          3              6.00                4.00
# 5      5   Autriche  Female         18              3.28                2.50
# 6      6   Autriche    Male          5              1.60                0.20
# 7      7    Bahamas  Female          1              1.00                0.00
# 8      8   Belgique  Female         37              2.41                1.89
# 9      9   Belgique    Male          8              3.13                1.75
#
#    meansellerpassrate  totalproductssold  totalproductslisted  \
# 0               27.33                468                  315
# 1               19.15                 68                   34
# 2                0.00                  0                   25
# 3               10.44                 17                   24
# 4               33.33                 18                   12
# 5               38.67                 59                   45
# 6               35.00                  8                    1
# 7                0.00                  1                    0
# 8               29.59                 89                   70
# 9               26.13                 25                   14
#
#    meanproductsbought  meanproductswished  meanproductsliked  totalbought  \
# 0                3.05               34.66              35.28          354
# 1                1.62                3.38              31.79           55
# 2                0.00                0.00               1.00            0
# 3                6.11               17.72             209.28          110
# 4                8.00               24.00              38.33           24
# 5                3.39               31.94              33.00           61
# 6                0.80                5.00               0.80            4
# 7                0.00                0.00               0.00            0
# 8               12.03               57.24              20.11          445
# 9                0.63                1.13               1.25            5
#
#    totalwished  totalproductsliked  meanfollowers  meanfollows  \
# 0         4021                4092            9.5          8.9
# 1          115                1081            7.8          8.4
# 2            0                   1            4.0          8.0
# 3          319                3767            7.5          9.3
# 4           72                 115           12.7          8.3
# 5          575                 594            6.9          8.4
# 6           25                   4            6.2          8.0
# 7            0                   0            4.0          8.0
# 8         2118                 744            8.3          8.5
# 9            9                  10            8.4          9.3
#
#    percentofappusers  percentofiosusers  meanseniority
# 0               54.0               49.0    3060.336207
# 1               79.0               64.0    3089.058824
# 2                NaN                NaN    3201.000000
# 3               55.0               55.0    3103.666667
# 4               66.0               66.0    3085.666667
# 5               61.0               50.0    3048.222222
# 6               60.0               60.0    3133.000000
# 7                NaN                NaN    2857.000000
# 8               62.0               48.0    3041.081081
# 9               62.0               37.0    3069.625000

# %%
# top sellers per country
country_top_sellers.head(10)
# Out:
#    index     country  sellers  topsellers  topsellerratio  femalesellersratio  \
# 0      0      Taiwan        1           1           100.0               100.0
# 1      1   Slovaquie        2           1            50.0                 0.0
# 2      2    Lettonie        4           2            50.0               100.0
# 3      3    Bulgarie        9           4            44.4                66.7
# 4      4      Chypre        4           1            25.0               100.0
# 5      5      Monaco        5           1            20.0               100.0
# 6      6    Roumanie       13           2            15.4                76.9
# 7      7  Luxembourg        7           1            14.3                85.7
# 8      8     Espagne      119          13            10.9                81.5
# 9      9      Italie      347          35            10.1                71.5
#
#    topfemalesellersratio  femalesellers  malesellers  topfemalesellers  ...  \
# 0                  100.0              1            0                 1  ...
# 1                    0.0              0            2                 0  ...
# 2                  100.0              4            0                 2  ...
# 3                  100.0              6            3                 4  ...
# 4                  100.0              4            0                 1  ...
# 5                  100.0              5            0                 1  ...
# 6                   50.0             10            3                 1  ...
# 7                  100.0              6            1                 1  ...
# 8                   76.9             97           22                10  ...
# 9                   65.7            248           99                23  ...
#
#    topmeanproductssold  topmeanproductslisted  meanproductssold  \
# 0            57.000000              56.000000         57.000000
# 1            27.000000              14.000000         14.000000
# 2            40.500000              18.000000         20.750000
# 3            36.250000              17.250000         18.888889
# 4            41.000000              66.000000         14.000000
# 5           170.000000              19.000000         38.000000
# 6            24.500000              19.500000          5.230769
# 7            30.000000               0.000000          6.142857
# 8            46.692308              23.153846          8.319328
# 9            39.685714              30.771429          8.126801
#
#    meanproductslisted  meanofflinedays  topmeanofflinedays  meanfollowers  \
# 0           56.000000             11.0                11.0           83.0
# 1            7.000000             17.0                15.0           10.5
# 2            9.000000            120.3                11.5           21.0
# 3            9.111111             98.3                19.0           28.6
# 4           20.250000             17.3                11.0           21.3
# 5            5.200000             51.6                12.0           39.6
# 6            5.923077            121.6                11.0           10.9
# 7            1.142857             73.6                11.0           15.9
# 8            4.991597            202.4                30.5           16.1
# 9            6.391931            141.8                26.5           16.1
#
#    meanfollowing  topmeanfollowers  topmeanfollowing
# 0            8.0              83.0               8.0
# 1            8.5              15.0               8.0
# 2           52.3              38.0              98.5
# 3           31.6              46.3              19.0
# 4           10.3              39.0              17.0
# 5            8.0             167.0               8.0
# 6           11.5              30.0              32.0
# 7            8.4              52.0               3.0
# 8           14.6              53.2              14.5
# 9           54.6              63.4             429.3
#
# [10 rows x 27 columns]

# %% [markdown]
# ### Pre-processing

# %%
# convert country code table into lower case
country_code["Name"] = country_code["Name"].apply(lambda x: str(x).lower())
country_code["Code"] = country_code["Code"].apply(lambda x: str(x).lower())

# %%
country_code.head()
# Out:
#              Name Code
# 0     afghanistan   af
# 1  ã…land islands   ax
# 2         albania   al
# 3         algeria   dz
# 4  american samoa   as

# %%
# checking no null values
user_level_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98913 entries, 0 to 98912
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                98913 non-null  int64
#  1   identifierHash       98913 non-null  int64
#  2   type                 98913 non-null  object
#  3   country              98913 non-null  object
#  4   language             98913 non-null  object
#  5   socialNbFollowers    98913 non-null  int64
#  6   socialNbFollows      98913 non-null  int64
#  7   socialProductsLiked  98913 non-null  int64
#  8   productsListed       98913 non-null  int64
#  9   productsSold         98913 non-null  int64
#  10  productsPassRate     98913 non-null  float64
#  11  productsWished       98913 non-null  int64
#  12  productsBought       98913 non-null  int64
#  13  gender               98913 non-null  object
#  14  civilityGenderId     98913 non-null  int64
#  15  civilityTitle        98913 non-null  object
#  16  hasAnyApp            98913 non-null  bool
#  17  hasAndroidApp        98913 non-null  bool
#  18  hasIosApp            98913 non-null  bool
#  19  hasProfilePicture    98913 non-null  bool
#  20  daysSinceLastLogin   98913 non-null  int64
#  21  seniority            98913 non-null  int64
#  22  seniorityAsMonths    98913 non-null  float64
#  23  seniorityAsYears     98913 non-null  float64
#  24  countryCode          98913 non-null  object
# dtypes: bool(4), float64(3), int64(12), object(6)
# memory usage: 16.2+ MB

# %%
# adding country names in english
user_level_data = pd.merge(user_level_data, 
                           country_code, 
                           left_on="countryCode",
                           right_on="Code",
                           how="left")

# %%
user_level_data.head()
# Out:
#    index       identifierHash  type     country language  socialNbFollowers  \
# 0      0 -7279641312655250028  user  Etats-Unis       en                  3
# 1      1 -1456013578740053406  user   Allemagne       de                  3
# 2      2  9006282053848196165  user       Suède       en                  3
# 3      3 -7154634866120535654  user     Turquie       en                  3
# 4      4  2858299215060733023  user      France       en                  3
#
#    socialNbFollows  socialProductsLiked  productsListed  productsSold  ...  \
# 0                8                    0               0             0  ...
# 1                8                    0               0             0  ...
# 2                8                    0               0             0  ...
# 3                8                    0               0             0  ...
# 4                8                    0               0             0  ...
#
#    hasAndroidApp  hasIosApp  hasProfilePicture daysSinceLastLogin  seniority  \
# 0          False      False               True                709       3205
# 1          False      False               True                709       3205
# 2          False       True               True                689       3205
# 3          False      False               True                709       3205
# 4          False       True               True                709       3205
#
#   seniorityAsMonths  seniorityAsYears  countryCode           Name  Code
# 0            106.83               8.9           us  united states    us
# 1            106.83               8.9           de        germany    de
# 2            106.83               8.9           se         sweden    se
# 3            106.83               8.9           tr         turkey    tr
# 4            106.83               8.9           fr         france    fr
#
# [5 rows x 27 columns]

# %%
# checking no null values
buyer_by_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      62 non-null     int64
#  1   country                    62 non-null     object
#  2   buyers                     62 non-null     int64
#  3   topbuyers                  62 non-null     int64
#  4   topbuyerratio              62 non-null     float64
#  5   femalebuyers               62 non-null     int64
#  6   malebuyers                 62 non-null     int64
#  7   topfemalebuyers            62 non-null     int64
#  8   topmalebuyers              62 non-null     int64
#  9   femalebuyersratio          62 non-null     float64
#  10  topfemalebuyersratio       33 non-null     float64
#  11  boughtperwishlistratio     57 non-null     float64
#  12  boughtperlikeratio         60 non-null     float64
#  13  topboughtperwishlistratio  32 non-null     float64
#  14  topboughtperlikeratio      33 non-null     float64
#  15  totalproductsbought        62 non-null     int64
#  16  totalproductswished        62 non-null     int64
#  17  totalproductsliked         62 non-null     int64
#  18  toptotalproductsbought     62 non-null     int64
#  19  toptotalproductswished     62 non-null     int64
#  20  toptotalproductsliked      62 non-null     int64
#  21  meanproductsbought         62 non-null     float64
#  22  meanproductswished         62 non-null     float64
#  23  meanproductsliked          62 non-null     float64
#  24  topmeanproductsbought      33 non-null     float64
#  25  topmeanproductswished      33 non-null     float64
#  26  topmeanproductsliked       33 non-null     float64
#  27  meanofflinedays            62 non-null     float64
#  28  topmeanofflinedays         33 non-null     float64
#  29  meanfollowers              62 non-null     float64
#  30  meanfollowing              62 non-null     float64
#  31  topmeanfollowers           33 non-null     float64
#  32  topmeanfollowing           33 non-null     float64
# dtypes: float64(19), int64(13), object(1)
# memory usage: 16.1+ KB

# %%
# checking no null values
seller_by_gender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                73 non-null     int64
#  1   country              70 non-null     object
#  2   sex                  72 non-null     object
#  3   nbsellers            73 non-null     int64
#  4   meanproductssold     73 non-null     float64
#  5   meanproductslisted   73 non-null     float64
#  6   meansellerpassrate   73 non-null     float64
#  7   totalproductssold    73 non-null     int64
#  8   totalproductslisted  73 non-null     int64
#  9   meanproductsbought   73 non-null     float64
#  10  meanproductswished   73 non-null     float64
#  11  meanproductsliked    73 non-null     float64
#  12  totalbought          73 non-null     int64
#  13  totalwished          73 non-null     int64
#  14  totalproductsliked   73 non-null     int64
#  15  meanfollowers        73 non-null     float64
#  16  meanfollows          73 non-null     float64
#  17  percentofappusers    66 non-null     float64
#  18  percentofiosusers    65 non-null     float64
#  19  meanseniority        73 non-null     float64
# dtypes: float64(11), int64(7), object(2)
# memory usage: 11.5+ KB

# %%
# checking no null values
country_top_sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   index                   19 non-null     int64
#  1   country                 19 non-null     object
#  2   sellers                 19 non-null     int64
#  3   topsellers              19 non-null     int64
#  4   topsellerratio          19 non-null     float64
#  5   femalesellersratio      19 non-null     float64
#  6   topfemalesellersratio   19 non-null     float64
#  7   femalesellers           19 non-null     int64
#  8   malesellers             19 non-null     int64
#  9   topfemalesellers        19 non-null     int64
#  10  topmalesellers          19 non-null     int64
#  11  countrysoldratio        19 non-null     float64
#  12  bestsoldratio           18 non-null     float64
#  13  toptotalproductssold    19 non-null     int64
#  14  totalproductssold       19 non-null     int64
#  15  toptotalproductslisted  19 non-null     int64
#  16  totalproductslisted     19 non-null     int64
#  17  topmeanproductssold     19 non-null     float64
#  18  topmeanproductslisted   19 non-null     float64
#  19  meanproductssold        19 non-null     float64
#  20  meanproductslisted      19 non-null     float64
#  21  meanofflinedays         19 non-null     float64
#  22  topmeanofflinedays      19 non-null     float64
#  23  meanfollowers           19 non-null     float64
#  24  meanfollowing           19 non-null     float64
#  25  topmeanfollowers        19 non-null     float64
#  26  topmeanfollowing        19 non-null     float64
# dtypes: float64(15), int64(11), object(1)
# memory usage: 4.1+ KB

# %% [markdown]
# <b>Observation:</b> All the four tables have non-null data points.

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# Unique number of users in the dataset

# %%
# unique number of users in the dataset
print(len(user_level_data.identifierHash.unique()))
# Out:
# 98913

# %% [markdown]
# Distribution of users by country

# %%
user_by_country = user_level_data.groupby(by=['Name']).agg({'identifierHash':['count']})
user_by_country.columns = ['_'.join(col) for col in user_by_country.columns.values]
user_by_country.sort_values(by = ["identifierHash_count"], ascending=False)
# Out:
#                         identifierHash_count
# Name
# france                                 25135
# united states                          20602
# united kingdom                         11310
# italy                                   8015
# germany                                 6567
# ...                                      ...
# sri lanka                                  1
# suriname                                   1
# svalbard and jan mayen                     1
# swaziland                                  1
# eritrea                                    1
#
# [196 rows x 1 columns]

# %%
user_by_country = user_by_country.reset_index()
fig = px.choropleth(
    data_frame=user_by_country,
    locations="Name",
    locationmode="country names",
    color="identifierHash_count",
    color_continuous_scale="Blues",
    range_color=[0, 600],
    title="Users by Country"
)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [152], line 1
# ----> 1 user_by_country = user_by_country.reset_index()
#       2 fig = px.choropleth(
#       3     data_frame=user_by_country,
#       4     locations="Name",
#    (...)
#       9     title="Users by Country"
#      10 )
#      11 fig.show()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5848, in DataFrame.reset_index(self, level, drop, inplace, col_level, col_fill)
#    5842         if lab is not None:
#    5843             # if we have the codes, extract the values with a mask
#    5844             level_values = algorithms.take(
#    5845                 level_values, lab, allow_fill=True, fill_value=lev._na_value
#    5846             )
# -> 5848         new_obj.insert(0, name, level_values)
#    5850 new_obj.index = new_index
#    5851 if not inplace:
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4443, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4437     raise ValueError(
#    4438         "Cannot specify 'allow_duplicates=True' when "
#    4439         "'self.flags.allows_duplicate_labels' is False."
#    4440     )
#    4441 if not allow_duplicates and column in self.columns:
#    4442     # Should this be a different kind of error??
# -> 4443     raise ValueError(f"cannot insert {column}, already exists")
#    4444 if not isinstance(loc, int):
#    4445     raise TypeError("loc must be int")
#
# ValueError: cannot insert level_0, already exists

# %% [markdown]
# Social Media followers/following per users

# %%
user_level_data.columns
# Out:
# Index(['index', 'identifierHash', 'type', 'country', 'language',
#        'socialNbFollowers', 'socialNbFollows', 'socialProductsLiked',
#        'productsListed', 'productsSold', 'productsPassRate', 'productsWished',
#        'productsBought', 'gender', 'civilityGenderId', 'civilityTitle',
#        'hasAnyApp', 'hasAndroidApp', 'hasIosApp', 'hasProfilePicture',
#        'daysSinceLastLogin', 'seniority', 'seniorityAsMonths',
#        'seniorityAsYears', 'countryCode', 'Name', 'Code'],
#       dtype='object')

# %%
# removing outlier from the dataset
user_followers = user_level_data.groupby(by=['socialNbFollowers']).agg({'identifierHash':['count']})
user_followers.columns = ["_".join(i) for i in user_followers.columns.values]
outliers = user_followers.query('identifierHash_count < 6').index.values
user_level_data_wo_follower_outlier = user_level_data.query("socialNbFollowers not in @outliers ")
px.histogram(user_level_data_wo_follower_outlier, x="socialNbFollowers")
# Out:
# <div>                            <div id="a0102911-63ca-427e-9d69-d078040a8e0b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a0102911-63ca-427e-9d69-d078040a8e0b")) {                    Plotly.newPlot(                        "a0102911-63ca-427e-9d69-d078040a8e0b",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"socialNbFollowers=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,6,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,31,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,5,3,3,3,3,3,3,3,3,3,4,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,28,3,3,3,3,3,4,3,3,3,3,3,3,3,3,3,3,3,3,7,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,4,3,3,3,3,3,3,3,3,3,3,3,10,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,4,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,5,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,4,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,4,3,3,3,3,3,4,3,3,3,3,6,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,4,3,3,3,3,3,18,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,7,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,4,3,3,3,3,3,3,3,3,4,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,6,3,3,3,3,4,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,4,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,16,3,5,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,8,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,4,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,4,3,3,3,3,3,3,3,3,3,3,3,3,3,3,6,3,3,3,3,3,3,3,3,3,3,3,3,4,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,5,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,4,3,3,3,3,3,3,3,3,3,3,8,3,3,3,4,3,3,3,3,3,3,3,3,3,3,3,3,3,3,27,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,4,3,3,3,3,3,3,3,3,5,3,3,4,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,4,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,29,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,5,3,3,3,3,5,3,5,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,4,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,29,5,3,3,3,3,3,3,3,3,5,3,3,3,3,16,3,3,3,3,3,3,3,3,3,3,24,3,3,3,3,4,3,3,3,3,3,3,3,3,3,3,3,3,3,8,4,3,3,26,3,3,4,3,3,3,3,3,3,3,3,3,9,3,3,3,3,3,3,3,3,3,3,3,3,3,4,3,3,3,3,3,5,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,4,3,3,3,3,3,3,11,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,4,3,3,3,3,3,3,8,3,11,3,3,3,3,3,3,3,3,3,3,3,3,4,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,6,3,3,3,3,3,3,3,3,3,3,3,3,3,3,5,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,5,3,3,3,3,3,3,3,4,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,5,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,6,3,4,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,28,3,3,3,3,3,7,3,3,3,3,3,3,3,3,3,3,23,5,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3, ...

# %%
user_following = user_level_data.groupby(by=['socialNbFollows']).agg({'identifierHash':['count']})
user_following.columns = ["_".join(x) for x in user_following.columns.values]
outliers = user_following.query('identifierHash_count < 6').index.values
user_level_data_wo_following_outlier = user_level_data.query("socialNbFollowers not in @outliers ")
px.histogram(user_level_data_wo_follower_outlier, x="socialNbFollows")
# Out:
# <div>                            <div id="75c54342-999f-4008-8b10-fdc4b5fe53bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75c54342-999f-4008-8b10-fdc4b5fe53bb")) {                    Plotly.newPlot(                        "75c54342-999f-4008-8b10-fdc4b5fe53bb",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"socialNbFollows=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,10,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,29,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,12,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,8,0,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,7,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,11,8,8,8,8,8,8,8,8,8,8,8,8,10,8,8,8,8,8,8,8,8,8,8,8,8,8,10,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,13,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,10,8,8,8,8,11,8,8,8,8,8,8,8,8,8,8,8,8,9,9,8,8,8,8,8,8,8,8,8,9,8,8,8,9,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,10,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,9,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,10,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,15,8,8,8,8,8,8,11,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,10,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,133,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,4,8,8,8,8,8,8,8,8,8,8,9,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8,8 ...

# %% [markdown]
# Gender wise distribution of users on the website

# %%
gender_wise_distribution = user_level_data.groupby(by=["civilityTitle"]).agg({'identifierHash':['count']})
gender_wise_distribution.columns = ["_".join(x) for x in gender_wise_distribution.columns.values]
gender_wise_distribution = gender_wise_distribution.reset_index()
sns.barplot(gender_wise_distribution, y='identifierHash_count', x="civilityTitle", palette=sns.color_palette(["#ADD8E6"]))
# Out:
# <AxesSubplot:xlabel='civilityTitle', ylabel='identifierHash_count'>

# %% [markdown]
# <b>Conclusion:</b> Majority of the users on the platfrom are women. There are a small number of women who are unmarried. So, In general majority of the users on the platform are married women.
